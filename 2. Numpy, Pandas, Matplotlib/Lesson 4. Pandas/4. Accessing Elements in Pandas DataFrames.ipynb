# %%
import pandas as pd

# %%
items = {"Abba": pd.Series([1,2,3], ["bikes","watches","clothes"]) ,
         "Jack": pd.Series([1,2,3], ["books","watches","clothes"]),
        "Manson": pd.Series([1,2,3], ["books","watches","clothes"])}
store_items = pd.DataFrame(items)
store_items
# Out:
#          Abba  Jack  Manson
# bikes     1.0   NaN     NaN
# books     NaN   1.0     1.0
# clothes   3.0   3.0     3.0
# watches   2.0   2.0     2.0

# %%
abba = store_items[["Abba", "Jack"]]
abba
# Out:
#          Abba  Jack
# bikes     1.0   NaN
# books     NaN   1.0
# clothes   3.0   3.0
# watches   2.0   2.0

# %%
abba_jack = store_items[["Abba", "Jack"]]
abba_jack
# Out:
#          Abba  Jack
# bikes     1.0   NaN
# books     NaN   1.0
# clothes   3.0   3.0
# watches   2.0   2.0

# %%
store_items.loc[["bikes", "books"]]
# Out:
#        Abba  Jack  Manson
# bikes   1.0   NaN     NaN
# books   NaN   1.0     1.0

# %%
store_items.loc[["bikes", "books"]][["Jack", "Abba"]]
# Out:
#        Jack  Abba
# bikes   NaN   1.0
# books   1.0   NaN

# %%
store_items["bikes"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\Udacity\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bikes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-3e0f10cce8b8> in <module>
# ----> 1 store_items["bikes"]
#
# ...

# %%
store_items["Marry"] = [1,2,3,4]
store_items
# Out:
#          Abba  Jack  Manson  Marry
# bikes     1.0   NaN     NaN      1
# books     NaN   1.0     1.0      2
# clothes   3.0   3.0     3.0      3
# watches   2.0   2.0     2.0      4

# %%
store_items["Alison"] = store_items["Abba"] + store_items["Jack"]
store_items
# Out:
#          Abba  Jack  Manson  Marry  Alison
# bikes     1.0   NaN     NaN      1     NaN
# books     NaN   1.0     1.0      2     NaN
# clothes   3.0   3.0     3.0      3     6.0
# watches   2.0   2.0     2.0      4     4.0

# %%
data2append = {"Abba": [10,10],
               "Jack": [20,20],
               "Manson": [30,30],
               "Marry": [40,40],
               "Alison": [50,50]}
df = pd.DataFrame(data2append, index= ["pandas", "pets"])
df
# Out:
#         Abba  Jack  Manson  Marry  Alison
# pandas    10    20      30     40      50
# pets      10    20      30     40      50

# %%
store_items = store_items.append(df)
store_items
# Out:
#          Abba  Jack  Manson  Marry  Alison
# bikes     1.0   NaN     NaN      1     NaN
# books     NaN   1.0     1.0      2     NaN
# clothes   3.0   3.0     3.0      3     6.0
# watches   2.0   2.0     2.0      4     4.0
# pandas   10.0  20.0    30.0     40    50.0
# pets     10.0  20.0    30.0     40    50.0

# %%
store_items["New Person"] = store_items["Abba"][1:]
store_items
# Out:
#          Abba  Jack  Manson  Marry  Alison  New Person
# bikes     1.0   NaN     NaN      1     NaN         NaN
# books     NaN   1.0     1.0      2     NaN         NaN
# clothes   3.0   3.0     3.0      3     6.0         3.0
# watches   2.0   2.0     2.0      4     4.0         2.0
# pandas   10.0  20.0    30.0     40    50.0        10.0
# pets     10.0  20.0    30.0     40    50.0        10.0

# %%
store_items.insert(3, "New Insert", [1,2,3,4,5,6])
store_items
# Out:
#          Abba  Jack  Manson  New Insert  Marry  Alison  New Person
# bikes     1.0   NaN     NaN           1      1     NaN         NaN
# books     NaN   1.0     1.0           2      2     NaN         NaN
# clothes   3.0   3.0     3.0           3      3     6.0         3.0
# watches   2.0   2.0     2.0           4      4     4.0         2.0
# pandas   10.0  20.0    30.0           5     40    50.0        10.0
# pets     10.0  20.0    30.0           6     40    50.0        10.0

# %%
store_items.pop("Manson")
store_items
# Out:
#          Abba  Jack  New Insert  Marry  Alison  New Person
# bikes     1.0   NaN           1      1     NaN         NaN
# books     NaN   1.0           2      2     NaN         NaN
# clothes   3.0   3.0           3      3     6.0         3.0
# watches   2.0   2.0           4      4     4.0         2.0
# pandas   10.0  20.0           5     40    50.0        10.0
# pets     10.0  20.0           6     40    50.0        10.0

# %%
store_items.drop(["Marry", "New Person"], axis = 1)
store_items
# Out:
#          Abba  Jack  New Insert  Marry  Alison  New Person
# bikes     1.0   NaN           1      1     NaN         NaN
# books     NaN   1.0           2      2     NaN         NaN
# clothes   3.0   3.0           3      3     6.0         3.0
# watches   2.0   2.0           4      4     4.0         2.0
# pandas   10.0  20.0           5     40    50.0        10.0
# pets     10.0  20.0           6     40    50.0        10.0

# %%
store_items = store_items.drop(["Marry", "New Person"], axis = 1)
store_items
# Out:
#          Abba  Jack  New Insert  Alison
# bikes     1.0   NaN           1     NaN
# books     NaN   1.0           2     NaN
# clothes   3.0   3.0           3     6.0
# watches   2.0   2.0           4     4.0
# pandas   10.0  20.0           5    50.0
# pets     10.0  20.0           6    50.0

# %%
store_items = store_items.drop(["bikes", "books"], axis = 0)
store_items
# Out:
#          Abba  Jack  New Insert  Alison
# clothes   3.0   3.0           3     6.0
# watches   2.0   2.0           4     4.0
# pandas   10.0  20.0           5    50.0
# pets     10.0  20.0           6    50.0

# %%
store_items.rename(columns = {"Abba": "Michael"})
store_items
# Out:
#          Abba  Jack  New Insert  Alison
# clothes   3.0   3.0           3     6.0
# watches   2.0   2.0           4     4.0
# pandas   10.0  20.0           5    50.0
# pets     10.0  20.0           6    50.0

# %%
store_items = store_items.rename(columns = {"Abba": "Michael"})
store_items
# Out:
#          Michael  Jack  New Insert  Alison
# clothes      3.0   3.0           3     6.0
# watches      2.0   2.0           4     4.0
# pandas      10.0  20.0           5    50.0
# pets        10.0  20.0           6    50.0

# %%
store_items = store_items.rename(index = {"pets": "shoes"})
store_items
# Out:
#          Michael  Jack  New Insert  Alison
# clothes      3.0   3.0           3     6.0
# watches      2.0   2.0           4     4.0
# pandas      10.0  20.0           5    50.0
# shoes       10.0  20.0           6    50.0
